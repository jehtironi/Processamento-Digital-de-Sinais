# %%
#Importando as bibliotecas que vão ser utilizadas

# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy import signal as sf

# %%
Fs = 8000

# %%
#Plotando a resposta em frequencia do exercicio 4 letra a

# %%
#Usando freqz para obter a resposta em frequencia
num = [3, -3.6];
den = [1, -1.4, 0.45];
[w, H] = sf.freqz(num, den, Fs)
plt.plot(w*Fs/(2*np.pi), 20*np.log10(abs(H)))
plt.title('Resposta em frequencia A')
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible=None, which='major', axis='both', **kwargs)>

# %%
#Plotando a resposta em frequencia do exercicio 4 letra b

# %%
#Usando freqz para obter a resposta em frequencia
num = 1;
den = [1, -2.1, 1.08];
[x, H] = sf.freqz(num, den, Fs)
plt.plot(x*Fs/(2*np.pi), 20*np.log10(abs(H)))
plt.title('Resposta em frequencia B')
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible=None, which='major', axis='both', **kwargs)>

# %%
#Plotando a resposta em frequencia do exercicio 4 letra c

# %%
#Usando freqz para obter a resposta em frequencia
num = [0, 1, 0.9];
den = [1, 1, 0.41];
[y, A] = sf.freqz(num, den, Fs)
plt.plot(y*Fs/(2*np.pi), 20*np.log10(abs(A)))
plt.title('Resposta em frequencia C')
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible=None, which='major', axis='both', **kwargs)>
